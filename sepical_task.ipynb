# %% [markdown]
# <a href="https://colab.research.google.com/github/ishwaridhage10-cpu/NumPy-Project/blob/main/sepical_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7adc9e9f-57a8-464c-a8c0-10c071b69063" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7adc9e9f-57a8-464c-a8c0-10c071b69063">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath="/content/players.csv"

# %%
import pandas as pd
df=pd.read_csv(filepath)

# %%
df.head()
# Out:
#              player     team team_country position     age  birth_year  \
# 0      Achref Abada  Algeria      Algeria       DF  27-020        1999
# 1     Adil Boulbina  Algeria      Algeria       FW  23-064        2003
# 2      Amine Gouiri  Algeria      Algeria       FW  26-139        2000
# 3  Anis Hadj Moussa  Algeria      Algeria       MF  24-144        2002
# 4       Aïssa Mandi  Algeria      Algeria       DF  34-256        1991
#
#         club  games  games_starts  minutes  ...  gk_wins  gk_ties  gk_losses  \
# 0        NaN      0             0      NaN  ...      NaN      NaN        NaN
# 1        NaN      2             0     19.0  ...      NaN      NaN        NaN
# 2  Marseille      4             3    251.0  ...      NaN      NaN        NaN
# 3  Feyenoord      3             1     98.0  ...      NaN      NaN        NaN
# 4      Lille      4             4    360.0  ...      NaN      NaN        NaN
#
#    gk_clean_sheets  gk_clean_sheets_pct  gk_pens_att  gk_pens_allowed  \
# ...

# %%
df.tail()
# Out:
#                   player        team team_country position     age  \
# 1242   Rustam Ashurmatov  Uzbekistan   Uzbekistan       DF  29-363
# 1243      Sherzod Esanov  Uzbekistan   Uzbekistan       MF  23-154
# 1244  Sherzod Nasrullaev  Uzbekistan   Uzbekistan    DF,MF  27-347
# 1245     Umar Eshmurodov  Uzbekistan   Uzbekistan       DF  33-217
# 1246       Utkir Yusupov  Uzbekistan   Uzbekistan       GK  35-182
#
#       birth_year       club  games  games_starts  minutes  ...  gk_wins  \
# 1242        1996  Esteghlal      3             3    256.0  ...      NaN
# 1243        2003        NaN      1             0      1.0  ...      NaN
# 1244        1998        NaN      3             3    180.0  ...      NaN
# 1245        1992        NaN      0             0      NaN  ...      NaN
# 1246        1991        NaN      1             1     90.0  ...      0.0
#
#       gk_ties  gk_losses  gk_clean_sheets  gk_clean_sheets_pct  gk_pens_att  \
# ...

# %%
df.shape
# Out:
# (1247, 72)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1247 entries, 0 to 1246
# Data columns (total 72 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   player                      1247 non-null   object
#  1   team                        1247 non-null   object
#  2   team_country                1247 non-null   object
#  3   position                    1247 non-null   object
#  4   age                         1247 non-null   object
#  5   birth_year                  1247 non-null   int64
#  6   club                        891 non-null    object
#  7   games                       1247 non-null   int64
#  8   games_starts                1247 non-null   int64
#  9   minutes                     1023 non-null   float64
#  10  minutes_90s                 1023 non-null   float64
#  11  goals                       1023 non-null   float64
#  12  assists                     1023 non-null   float64
# ...

# %%
df.describe()
# Out:
#         birth_year        games  games_starts      minutes  minutes_90s  \
# count  1247.000000  1247.000000   1247.000000  1023.000000  1023.000000
# mean   1998.036889     2.277466      1.587811   177.093842     1.966960
# std       4.257022     1.487777      1.543415   120.837695     1.341576
# min    1982.000000     0.000000      0.000000     1.000000     0.000000
# 25%    1995.000000     1.000000      0.000000    67.500000     0.750000
# 50%    1998.000000     3.000000      1.000000   173.000000     1.900000
# 75%    2001.000000     4.000000      3.000000   270.000000     3.000000
# max    2008.000000     5.000000      5.000000   480.000000     5.300000
#
#              goals      assists  goals_assists   goals_pens    pens_made  ...  \
# count  1023.000000  1023.000000    1023.000000  1023.000000  1023.000000  ...
# mean      0.242424     0.185728       0.428152     0.231672     0.010753  ...
# std       0.693751     0.510853       0.942822     0.662154     0.103187  ...
# ...

# %%
df.columns
# Out:
# Index(['player', 'team', 'team_country', 'position', 'age', 'birth_year',
#        'club', 'games', 'games_starts', 'minutes', 'minutes_90s', 'goals',
#        'assists', 'goals_assists', 'goals_pens', 'pens_made', 'pens_att',
#        'cards_yellow', 'cards_red', 'goals_per90', 'assists_per90',
#        'goals_assists_per90', 'goals_pens_per90', 'goals_assists_pens_per90',
#        'shots', 'shots_on_target', 'shots_on_target_pct', 'shots_per90',
#        'shots_on_target_per90', 'goals_per_shot', 'goals_per_shot_on_target',
#        'minutes_per_game', 'minutes_pct', 'minutes_per_start',
#        'games_complete', 'games_subs', 'minutes_per_sub', 'unused_subs',
#        'points_per_game', 'on_goals_for', 'on_goals_against', 'plus_minus',
#        'plus_minus_per90', 'plus_minus_wowy', 'cards_yellow_red', 'fouls',
#        'fouled', 'offsides', 'crosses', 'interceptions', 'tackles_won',
#        'pens_won', 'pens_conceded', 'own_goals', 'gk_games', 'gk_games_starts',
# ...

# %%
df.dtypes
# Out:
# player               object
# team                 object
# team_country         object
# position             object
# age                  object
#                      ...
# gk_pens_att         float64
# gk_pens_allowed     float64
# gk_pens_saved       float64
# gk_pens_missed      float64
# gk_pens_save_pct    float64
# Length: 72, dtype: object

# %%
df.isnull().sum()
# Out:
# player                 0
# team                   0
# team_country           0
# position               0
# age                    0
#                     ...
# gk_pens_att         1187
# gk_pens_allowed     1187
# gk_pens_saved       1187
# gk_pens_missed      1187
# gk_pens_save_pct    1236
# Length: 72, dtype: int64

# %%
df.nunique()
# Out:
# player              1246
# team                  48
# team_country          48
# position               9
# age                 1114
#                     ...
# gk_pens_att            3
# gk_pens_allowed        3
# gk_pens_saved          2
# gk_pens_missed         2
# gk_pens_save_pct       2
# Length: 72, dtype: int64

# %%
df.sample(5)
# Out:
#                 player            team    team_country position     age  \
# 1205  Joaquín Piquerez         Uruguay         Uruguay    DF,MF  27-315
# 682       Jo Hyeon-woo  Korea Republic  Korea Republic       GK  34-283
# 696       Park Jinseob  Korea Republic  Korea Republic    DF,MF  30-255
# 1055     Nico Williams           Spain           Spain       MF  23-358
# 758      Donyell Malen     Netherlands     Netherlands       FW  27-177
#
#       birth_year           club  games  games_starts  minutes  ...  gk_wins  \
# 1205        1998            NaN      0             0      NaN  ...      NaN
# 682         1991            NaN      0             0      NaN  ...      NaN
# 696         1995       Zhejiang      2             0     32.0  ...      NaN
# 1055        2002  Athletic Club      3             0     48.0  ...      NaN
# 758         1999           Roma      3             3    185.0  ...      NaN
#
# ...

# %%
df.value_counts()
# Out:
# Series([], Name: count, dtype: int64)
